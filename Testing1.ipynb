# %% [markdown]
# # Proyecto batalla pokemon

# %% [markdown]
# ## Imports

# %%
# %pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/11.0 MB 1.9 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.3/11.0 MB 2.2 MB/s eta 0:00:05
#    ------ --------------------------------- 1.8/11.0 MB 2.2 MB/s eta 0:00:05
#    -------- ------------------------------- 2.4/11.0 MB 2.3 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.9/11.0 MB 2.3 MB/s eta 0:00:04
#    ----------- ---------------------------- 3.1/11.0 MB 2.4 MB/s eta 0:00:04
#    -------------- ------------------------- 3.9/11.0 MB 2.4 MB/s eta 0:00:03
#    ----------------- ---------------------- 4.7/11.0 MB 2.5 MB/s eta 0:00:03
#    -------------------- ------------------- 5.5/11.0 MB 2.6 MB/s eta 0:00:03
#    --------------------- ------------------ 6.0/11.0 MB 2.6 MB/s eta 0:00:02
# ...

# %%
import pandas as pd
import random

# %%
# Opcion para ver el mayor numero de columnas disponibles
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Paths

# %%
PATH = './pokemon.csv'

# %% [markdown]
# ## Data Extraction/mining

# %% [markdown]
# Extraje este dataset del siguinte link: ''

# %%
pokemons_raw = pd.read_csv(PATH)

# %% [markdown]
# ## Data Manipulation

# %% [markdown]
# Revisando las columnas del dataset para saber cuales son las que serán utiles para el programa

# %%
pokemons_raw.head()
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  against_grass  against_ground  against_ice  \
# ...

# %% [markdown]
# Seleccionando las columnas que no voy a necesitar

# %%
deleted_columns = ['abilities','base_egg_steps','base_happiness','capture_rate','classfication','experience_growth','height_m','japanese_name','percentage_male','weight_kg','generation']

# %% [markdown]
# ## Data cleaning

# %%
pokemons_raw.drop(columns= deleted_columns, inplace=True)

# %%
pokemons_raw.set_index('name', inplace=True)

# %%
pokemons_clean = pokemons_raw[:151].copy()

# %% [markdown]
# ## Class

# %% [markdown]
# Empiezo a definir la clase pokemon

# %%
class Pokemon:
  def __init__(self, name, pokemon_enemigo=False, difficulty=None):
    pokemon_enemigo = pokemons_clean.sample(n=1).index[0]
    self.name = name
    self.type1 = pokemons_clean.loc[self.name, 'type1']
    self.type2 = pokemons_clean.loc[self.name, 'type2']
    self.hp = pokemons_clean.loc[self.name, 'hp']
    self.attack = pokemons_clean.loc[self.name, 'attack']
    self.defense = pokemons_clean.loc[self.name, 'defense']
    self.speed =  pokemons_clean.loc[self.name, 'speed']
    self.base = pokemons_clean.loc[self.name, 'base_total']
